# %%
# !pip install fuzzywuzzy

# %%
import os
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-1550ba64-85db-404e-857e-5c320fcb8948" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1550ba64-85db-404e-857e-5c320fcb8948">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#df1 = pd.read_csv('FINALMANUAL.csv', encoding='unicode_escape')
df3 = pd.read_csv('FManual.csv', encoding='unicode_escape')
#df3 = pd.read_csv('test3.csv')

# %%
#df1 =df1.drop_duplicates()
#df2 =df2.drop_duplicates()
#df3 =df3.drop_duplicates()

# %%
combinedtest = pd.concat([df1, df2, df3], ignore_index=True)

# %%
combinedtest
# Out:
#                          Company
# 0               Adams Express Co
# 1     Advanced Micro Devices Inc
# 2     Advanced Micro Devices Inc
# 3     Advanced Micro Devices Inc
# 4     Advanced Micro Devices Inc
# ...                          ...
# 5646                 Wells Fargo
# 5647                Weyerhaeuser
# 5648          Whole Foods Market
# 5649        Winnebago Industries
# 5650           Wrigley (Wm.) Jr.
#
# [5651 rows x 1 columns]

# %%
#combined_df = combined_df.drop_duplicates()

# %%
#combined =combined_df.sort_values("Company")

# %%
combinedtest.to_csv('./combinedtest.csv', sep = ',', index = False)

# %%
files.download('combinedtest.csv')

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-902235a1-c54f-48df-8199-077cf90893b8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-902235a1-c54f-48df-8199-077cf90893b8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df2= pd.read_csv('mergefinal.csv')

# %%
df3
# Out:
#                           Company        cusip
# 0    21st Century Insurance Group  90130N 10 3
# 1                Adams Express Co      6212104
# 2                           Aetna   00817Y108
# 3           Aetna Life & Casualty   00817Y108
# 4                Airborne Freight    009269101
# ..                            ...          ...
# 610                         Xerox   98421M 106
# 611                    Xerox Corp   98421M 106
# 612                        Zapata    989070107
# 613                   Zapata Corp    989070107
# 614                          Zero            0
#
# [615 rows x 2 columns]

# %%
df2
# Out:
#                                       Company  Cusip
# 0                21st Century Insurance Group      0
# 1                            Adams Express Co      0
# 2                            Adams Express Co      0
# 3     Advanced Micro Devices-adj. to 05/25/00      0
# 4                                       Aetna      0
# ...                                       ...    ...
# 3597                                   Zapata      0
# 3598                              Zapata Corp      0
# 3599                              Zapata Corp      0
# 3600                                     Zero      0
# 3601                                     Zero      0
#
# [3602 rows x 2 columns]

# %%
unnamed_columns = [col for col in df4.columns if col.startswith('matches')]

# Drop unnamed columns
df4 = df4.drop(columns=unnamed_columns)

# %%
named_columns = [col for col in df4.columns if col.startswith('conm')]

# Drop unnamed columns
df4 = df4.drop(columns=named_columns)

# %%
df4
# Out:
#                          Company      cusip
# 0                        AMP INC   31897101
# 1         ADVANCED MICRO DEVICES    7903107
# 2               ADVEST GROUP INC    7566102
# 3    AGOURON PHARMACEUTICALS INC    8488108
# 4            AHMANSON (H F) & CO    8677106
# ..                           ...        ...
# 415       WHOLE FOODS MARKET INC  966837106
# 416         WINNEBAGO INDUSTRIES  974637100
# 417           WRIGLEY (WM) JR CO  982526105
# 418                  YELLOW CORP  985510106
# 419      ZENITH ELECTRONICS CORP  989349105
#
# [420 rows x 2 columns]

# %%
combinedtest
# Out:
#                          Company
# 0               Adams Express Co
# 1     Advanced Micro Devices Inc
# 2     Advanced Micro Devices Inc
# 3     Advanced Micro Devices Inc
# 4     Advanced Micro Devices Inc
# ...                          ...
# 5646                 Wells Fargo
# 5647                Weyerhaeuser
# 5648          Whole Foods Market
# 5649        Winnebago Industries
# 5650           Wrigley (Wm.) Jr.
#
# [5651 rows x 1 columns]

# %%
result = pd.DataFrame(df2)

key = pd.DataFrame(df3)

for i in range(0,len(result)):
  for j in range(0,len(key)):
    if((fuzz.ratio(result.at[i,'Company'], key.at[j,'Company']))>=90):
      result.at[i,'cusip'] = key.at[j,'cusip']
    # if(fuzz.ratio(result.at[i,'Company'], key.at[j,'Company']) >= 80):
    #   result.at[i,'cusip'] = key.at[j,'cusip']
    result

# %%
result
# Out:
#                                       Company  Cusip        cusip
# 0                21st Century Insurance Group      0  90130N 10 3
# 1                            Adams Express Co      0      6212104
# 2                            Adams Express Co      0      6212104
# 3     Advanced Micro Devices-adj. to 05/25/00      0          NaN
# 4                                       Aetna      0   00817Y108
# ...                                       ...    ...          ...
# 3597                                   Zapata      0    989070107
# 3598                              Zapata Corp      0    989070107
# 3599                              Zapata Corp      0    989070107
# 3600                                     Zero      0            0
# 3601                                     Zero      0            0
#
# [3602 rows x 3 columns]

# %%
result.to_csv('./result.csv', sep = ',', index = False)

# %%
files.download('result.csv')

# %%
f1 = pd.DataFrame(combinedtest)
f2 = pd.DataFrame(df4)
for company in f1:
  threshold = 80
  matches = f1['Company'].apply(lambda x: process.extractOne(x, f2['Company'], scorer=fuzz.ratio))
  match_values = [match[0] if match[1] >= threshold else None for match in matches]
  print(matches, match_values)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-efb6d69187a5> in <cell line: 3>()
#       3 for company in f1:
#       4   threshold = 80
# ----> 5   matches = f1['Company'].apply(lambda x: process.extractOne(x, f2['Company'], scorer=fuzz.ratio))
#       6   match_values = [match[0] if match[1] >= threshold else None for match in matches]
#       7   print(matches, match_values)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4769         dtype: float64
#    4770         """
# -> 4771         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4772
#    4773     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1121
#    1122         # self.f is Callable
# -> 1123         return self.apply_standard()
#    1124
# ...

# %%
df1 = pd.DataFrame(combinedtest)
df2= pd.DataFrame(result)
threshold = 80
matched_names=[]
for row1 in df1.index:
    name1 = df1._get_value(row1,"Company") #Name1 is the column name of df1 of an entity to be matched
    for row2 in df2.index:
        name2= df2._get_value(row2,"Company")  #Name2 is the column name of df2 of entity to be matched
        matched_token=fuzz.partial_ratio(name1,name2)
        if matched_token> 80: #This is the threshold, you can change according to your neds
            matched_names.append([name1,name2,matched_token])



matched_names
# Out:
# [['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
#  ['CSX', 'CSX CORP', 100],
# ...

# %%
ff1 = pd.DataFrame(combinedtest)
ff2 = pd.DataFrame(df4)

# Define a fuzzy matching threshold
threshold = 80

# Perform fuzzy matching using fuzzywuzzy's process module
matches = ff1['Company'].apply(lambda x: process.extractOne(x, ff2['Company'], scorer=fuzz.ratio))

# Extract the matched values and their corresponding indices
match_values = [match[0] if match[1] >= threshold else None for match in matches]
match_indices = [i if match[1] >= threshold else None for i, match in enumerate(matches)]


# Create a new DataFrame with the matched values and merge it with df2 based on the matched values
matched_df = pd.DataFrame({'Company': match_values})
result = pd.merge(matched_df, df4, left_on='Company', right_on='Company', how='inner')

# %%
matches.size
# Out:
# 5651

# %%
matches
# Out:
# 0           (AMERICAN EXPRESS CO, 74, 20)
# 1         (ADVANCED MICRO DEVICES, 92, 1)
# 2         (ADVANCED MICRO DEVICES, 92, 1)
# 3         (ADVANCED MICRO DEVICES, 92, 1)
# 4         (ADVANCED MICRO DEVICES, 92, 1)
#                       ...
# 5646          (WELLS FARGO & CO, 81, 408)
# 5647           (WEYERHAEUSER CO, 89, 412)
# 5648    (WHOLE FOODS MARKET INC, 90, 415)
# 5649     (WINNEBAGO INDUSTRIES, 100, 416)
# 5650        (WRIGLEY (WM) JR CO, 88, 417)
# Name: Company, Length: 5651, dtype: object

# %%
def fuzzy_merge(df_1, df_2, key1, key2, threshold=80, limit=10):
 s = df_2[key2].tolist()
 m = df_1[key1].apply(lambda x: process.extract(x, s, limit=limit))
 df_1['matches'] = m


 m2 = df_1['matches'].apply(lambda x: ', '.join([i[0] for i in x if i[1] >= threshold]))
 df_1['matches'] = m2


 return df_1

# %%
merge1= fuzzy_merge(combinedtest,combinedtest, 'Company', 'Company', threshold=90)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/process.py in extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     107         # See if choices is a dictionary-like object.
# --> 108         for key, choice in choices.items():
#     109             processed = pre_processor(processor(choice))
#
# AttributeError: 'list' object has no attribute 'items'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-9d31a7c84370> in <cell line: 1>()
# ----> 1 merge1= fuzzy_merge(combinedtest,combinedtest, 'Company', 'Company', threshold=90)
#
# <ipython-input-29-a89da3b7c0c7> in fuzzy_merge(df_1, df_2, key1, key2, threshold, limit)
# ...

# %%
result.to_csv('./result1', sep = ',', index = False)

# %%
files.download('result.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-74-20b258b533cd> in <cell line: 1>()
# ----> 1 files.download('result.csv')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/files.py in download(filename)
#     223   if not _os.path.exists(filename):
#     224     msg = 'Cannot find file: {}'.format(filename)
# --> 225     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     226
#     227   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: result.csv

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-23af13df-b090-4c3d-b383-075553158cb4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-23af13df-b090-4c3d-b383-075553158cb4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#final1 = pd.read_csv('final1.csv')

# %%
#merge2= fuzzy_merge(final1, final1, 'Company', 'Company', threshold=90)

# %%
#merge2

# %%
#uploaded = files.upload()

# %%
df=pd.read_csv('CompustatCompany.csv')

# %%
#df =df.drop_duplicates()

# %%
unnamed_columns = [col for col in df.columns if col.startswith('Unnamed')]

# Drop unnamed columns
df = df.drop(columns=unnamed_columns)

# %%
df = df.sort_values("conm")

# %%
df.drop_duplicates()
# Out:
#                                 conm      cusip
# 333139       007 PRECIOUS METALS INC  98949J106
# 467258  01 COMMUNIQUE LABORATORY INC  67088Q106
# 437613               0373849 B C LTD  98952A109
# 131074                1 POTATO 2 INC  682410204
# 431501            1-800 CONTACTS INC  681977104
# ...                              ...        ...
# 198509             ZYTEC SYSTEMS INC  98987H103
# 194908                   ZYTREX CORP  989875109
# 240595       ZYUS LIFE SCIENCES CORP  989960109
# 386416      ZYVERSA THERAPEUTICS INC  98987D102
# 212736              ZZZZ BEST CO INC  988805206
#
# [42819 rows x 2 columns]

# %%
ff1 = pd.DataFrame(combined_df)
ff2 = pd.DataFrame(df)

# Define a fuzzy matching threshold
threshold = 80

# Perform fuzzy matching using fuzzywuzzy's process module
matches = ff1['Company'].apply(lambda x: process.extractOne(x, ff2['conm'], scorer=fuzz.ratio))

# Extract the matched values and their corresponding indices
match_values = [match[0] if match[1] >= threshold else None for match in matches]
match_indices = [i if match[1] >= threshold else None for i, match in enumerate(matches)]

# Create a new DataFrame with the matched values and merge it with df2 based on the matched values
matched_df = pd.DataFrame({'Company': match_values})
result = pd.merge(matched_df, df, left_on='Company', right_on='conm', how='inner')

# %%
#result= result.drop_duplicates()

# %%
result

# %%
result.to_csv('./result.csv', sep = ',', index = False)

# %%
files.download('result.csv')

# %%
merge= fuzzy_merge(final1, result, 'Company', 'Company', threshold=90)

# %%
merge

# %%
merge.to_csv('./merge.csv', sep = ',', index = False)

# %%
files.download('merge.csv')

# %%
f1 = pd.DataFrame(merge)
f2 = pd.DataFrame(result)

# Define a fuzzy matching threshold
threshold = 90

# Perform fuzzy matching using fuzzywuzzy's process module
matches1 = f1['matches'].apply(lambda x: process.extractOne(x, f2['Company'], scorer=fuzz.ratio))

# Extract the matched values and their corresponding indices
match_values1 = [match[0] if match[1] >= threshold else None for match in matches1]
match_indices1 = [i if match[1] >= threshold else None for i, match in enumerate(matches1)]

# Create a new DataFrame with the matched values and merge it with df2 based on the matched values
matched_df1 = pd.DataFrame({'matches': match_values1})
result1 = pd.merge(matched_df1, result , left_on='matches', right_on='Company', how='inner')

# %%
result1= result1.drop_duplicates()

# %%
result1

# %%
result1.to_csv('./result1.csv', sep = ',', index = False)

# %%
files.download('result1.csv')

# %%
merge11= fuzzy_merge(final1, result1, 'Company', 'conm', threshold=90)

# %%
merge11

# %%
merge11.to_csv('./merge11.csv', sep = ',', index = False)

# %%
files.download('merge11.csv')
